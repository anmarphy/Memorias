# %% [markdown]
# # Operaciones con filas

# %% [raw]
# Este script contiene cuatro elementos esenciales del data wrangling:
# 1. Unión de conjuntos
# 2. Concatenación de varios ficheros que conforman el dataset
# 3. Joins
# 4. Insertando datos

# %%
import pandas as pd

# %% [markdown]
# ## 1. Unión de conjuntos

# %% [raw]
# Se cargan dos conjuntos de datos, el primero asociado a vino tinto y el segundo a vino blanco, estos conjuntos de datos poseen los mismos atributos, el objetivo es pegar un conjunto debajo del otro.

# %%
main_path="C:/Users/Andrea/Desktop/python-ml-course-master/datasets/wine"
tinto="winequality-red.csv"
blanco="winequality-white.csv"

# %%
data_red=pd.read_csv(main_path+"/"+tinto, sep=";")
data_blanco=pd.read_csv(main_path+"/"+blanco, sep=";")

# %%
data_red.tail(n=2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1597     10.2        5
# 1598     11.0        6

# %%
data_blanco.tail(n=2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4896     12.8        7
# 4897     11.8        6

# %% [markdown]
# #### Concatenando axis=0

# %%
data_wine=pd.concat([data_red, data_blanco], axis=0)

# %%
data_wine.shape
# Out:
# (6497, 12)

# %% [markdown]
# ## 2. Concatenación de varios ficheros que conforman el dataset

# %% [markdown]
# #### Cargando el primer fichero

# %%
main_path_v="C:/Users/Andrea/Desktop/python-ml-course-master/datasets/distributed-data"
data=pd.read_csv(main_path_v+"/"+"001.csv")

# %%
data.head(n=2)
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1

# %%
for i in range(2,323):
    if i<10 :
        file_name="00"+str(i)
    if 9<i<100:
         file_name="0"+str(i)
    if 99<i<323:
        file_name=str(i)
    file_path=main_path_v+"/"+file_name+".csv"
    temp_data=pd.read_csv(file_path)
    data=pd.concat([data, temp_data], axis=0)

# %%
len(data)
# Out:
# 750174

# %%
data.shape
# Out:
# (750174, 4)

# %% [markdown]
# ## 3. Joins

# %%
carpeta="C:/Users/Andrea/Desktop/python-ml-course-master/datasets/athletes"
medallas="Medals.csv"
paises="Athelete_Country_Map.csv"
atletas="Athelete_Sports_Map.csv"

# %%
med=pd.read_csv(carpeta+"/"+medallas, encoding="ISO-8859-1")
med.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %% [raw]
# Podemos ver que en medallas puede aparecer el mismo atleta varias veces. Veamos cuantos atletas diferentes hay en el archivo

# %%
a=med["Athlete"].unique().tolist()
len(a)
# Out:
# 6956

# %%
pais=pd.read_csv(carpeta+"/"+paises, encoding="ISO-8859-1")
pais.head(n=2)
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States

# %%
mer_inner=pd.merge(left=med, right=pais, 
                  how="inner", left_on="Athlete", right_on="Athlete")

# %%
mer_inner.head(n=2)
# Out:
#           Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Michael Phelps  23.0  2008            08/24/2008            8
# 1  Michael Phelps  19.0  2004            08/29/2004            6
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States

# %%
mer_left=pd.merge(left=med, right=pais, 
                  how="left", left_on="Athlete", right_on="Athlete")

# %% [markdown]
# ## 4. Insertando datos

# %%
pais.append({
    "Athlete": "Andrea Marcela",
    "Country" : "Brazil"
},ignore_index=True
)
# Out:
#                             Athlete         Country
# 0                    Michael Phelps   United States
# 1                  Natalie Coughlin   United States
# 2                     Aleksey Nemov          Russia
# 3                     Alicia Coutts       Australia
# 4                    Missy Franklin   United States
# 5                       Ryan Lochte   United States
# 6                   Allison Schmitt   United States
# 7                        Ian Thorpe       Australia
# 8                       Dara Torres   United States
# 9                     Cindy Klassen          Canada
# 10                    Nastia Liukin   United States
# 11                    Marit Bjørgen          Norway
# 12                         Sun Yang           China
# 13                  Kirsty Coventry        Zimbabwe
# 14            Libby Lenton-Trickett       Australia
# 15                   Inge de Bruijn     Netherlands
# 16                    Petria Thomas       Australia
# ...
